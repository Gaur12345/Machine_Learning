# %%
import bs4
import requests

# %%
url="https://www.mycodingzone.net/blog/english"
data=requests.get(url)
soup = bs4.BeautifulSoup(data.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <meta content="B9A07A53598C8C5CB664364E44372C1F" name="msvalidate.01">
#    <meta content="505405866474484" property="fb:app_id">
#     <title>
#      My Coding Zone
#     </title>
#     <!-- Bootstrap -->
#     <link href="/static/css/bootstrap.min.css" rel="stylesheet"/>
#     <link href="/static/css/prism.css" rel="stylesheet"/>
#     <link href="/static/css/carousel.css" rel="stylesheet"/>
#     <link href="/static/photo.png" rel="shortcut icon"/>
#     <script src="https://apis.google.com/js/platform.js">
#     </script>
#     <script>
#      (function(i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function() {
# ...

# %%
for para in soup.find('p'):
    print(para)
# Out:
# Before I start telling you about wheel files and how to install them, I would like to tell you about their significance. We all generally use pip to install python modules which fails at times. In such situations, we have no other option than to search for error on stackoverflow or post it on forums.
#
#
#
#
#
#
#
#
# But if you face any problem down...

# %%
for para in soup.find_all('p'):
    print(para)
# Out:
# <p>Before I start telling you about wheel files and how to install them, I would like to tell you about their significance. We all generally use pip to install python modules which fails at times. In such situations, we have no other option than to search for error on stackoverflow or post it on forums.
#
#
#
#
#
#
#
#
# But if you face any problem down...</p>
# <p>
# When I started my python journey and tried to install a package using pip from the command line, I faced the same issue.
#
#
# Error:
#   A better version of this tutorial is available! Click here to read the updated solution to the problem!
#
#
#
#
#
#
#
#
# At that time i wish someone could have told me how to fix the same.
# In this post, I am going to te...</p>
# ...

# %%
for para in soup.find_all('p'):
    print(para.text)
# Out:
# Before I start telling you about wheel files and how to install them, I would like to tell you about their significance. We all generally use pip to install python modules which fails at times. In such situations, we have no other option than to search for error on stackoverflow or post it on forums.
#
#
#
#
#
#
#
#
# But if you face any problem down...
#
# When I started my python journey and tried to install a package using pip from the command line, I faced the same issue.
#
#
# Error:
#   A better version of this tutorial is available! Click here to read the updated solution to the problem!
#
#
#
#
#
#
#
#
# At that time i wish someone could have told me how to fix the same.
# In this post, I am going to te...
# ...

# %%
for links in soup.find_all('a'):
    link=links.get('href')
    if link[0:3]== "../" and link!="#":
        print("https://www.mycodingzone.net" + link[2:len(link)])
# Out:
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# https://www.mycodingzone.net/blogpost/english/how-many-similar-rectangles-will-fit-inside-a-larger-rectangle-of-given-size
# https://www.mycodingzone.net/blogpost/english/how-many-similar-rectangles-will-fit-inside-a-larger-rectangle-of-given-size

# %%
for links in soup.find_all('a'):
    link=links.get('href')
    if link[0:3]== "../" and link!="#":
        print("https://www.mycodingzone.net" + link[2:len(link)])
    elif link[0] =="/" and link!="#":
        print("https://www.mycodingzone.net "+link)
    elif link!="#":
        print(link)
# Out:
# https://www.mycodingzone.net /english
# https://www.mycodingzone.net /english
# https://www.mycodingzone.net /tutorials/python/english/getting-started-with-python
# https://www.mycodingzone.net /blog/english
# https://www.mycodingzone.net /videos/english
# https://www.mycodingzone.net /hire/english
# https://www.mycodingzone.net /english
# https://www.mycodingzone.net /hindi
# https://www.mycodingzone.net /hindi-devnagri
# https://www.mycodingzone.net /blog/hindi
# https://www.mycodingzone.net /blog/hindi-devnagri
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# ...

# %%
for links in soup.find_all('div'):
    print(links)
# Out:
# <div class="container">
# <div class="container">
# <br/>
# </div>
# <!-- Static navbar -->
# <nav class="navbar navbar-default">
# <div class="container-fluid">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/english">
# <img alt="Brand" src="/static/photo.png" style="max-width:47px; margin-top : -14px;"/>
# </a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li><a href="/english">Home</a></li>
# <li class="dropdown">
# ...

# %%
for links in soup.find_all('script'):
    print(links)
# Out:
# <script src="https://apis.google.com/js/platform.js"></script>
# <script>
#     (function(i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function() {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-60726752-2', 'auto');
#     ga('send', 'pageview');
#     </script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-9655830461045889",
#           enable_page_level_ads: true
#      });
# </script>
# <script>
# (function(d, s, id) {
# ...

# %%
import http.cookiejar
import urllib.request

# %%
cj = http.cookiejar.CookieJar()
opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))

urllib.request.install_opener(opener)

authentication_url = "https://m.facebook.com/login.php"
payload = {

    'email':"8405878976",
    'pass':"9122711791"
}
data = urllib.parse.urlencode(payload).encode('utf-8')
req = urllib.request.Request(authentication_url, data)
resp = urllib.request.urlopen(req)
contents = resp.read()
print(contents)
# Out:
# b'<?xml version="1.0" encoding="utf-8"?>\n<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml"><head><title>Facebook</title><meta name="referrer" content="default" id="meta_referrer" /><style type="text/css">/*<![CDATA[*/.bj{padding:6px;}.b .bk{padding:2px 4px;}.b .cg{border:1px solid #8d949e;border-radius:72px;height:45px;padding:4px 20px 0 20px;resize:none;}.ce{border-color:#90949c;box-sizing:border-box;width:100%;}.ce.cf{margin-top:6px;}.b .ci{height:45px;margin:6px 0 0 5px;width:75px;}.b .ca{border:1px solid #8d949e;height:43px;margin:6px 4px;width:43px;}.bz{padding-right:4px;}.ch{padding-left:4px;}.bm{margin-top:4px;}.bw{display:inline-block;}.bw .bx{color:#4b4f56;display:block;font-size:small;text-align:left;white-space:normal;}.dd{background:#f5f6f7;}.e{background:#dddfe2;}.da{background:#fff;}form{margin:0;border:0;}.b .m{border:0;border-collapse:collapse;margin:0;padding:0;wi
# ...

# %%
url2="https://m.facebook.com/viksharma7488/friends"
data=requests.get(url2,cookies=cj)
soup=bs4.BeautifulSoup(data.text,'html.parser')

for i in soup.find_all('a'):
    print(i.text)
    
print("After first inreation \n")
# Out:
# Home
# Profile
# Messages(1)
# Notifications(2)
# Chat(18)
# Friends(58)
# Menu
#
# Message
# More
# Timeline
# About
# Photos
# Likes
# Following
# 7 Mutual Friends
# Satyam Kapoor
# Add Friend
# Rïtwîk Mishrä
# Add Friend
# Sushank Pandey
# Add Friend
# Umang Kashyap
# Add Friend
# Nihal Kumar
# Add Friend
# Chitransh Ayush
# Add Friend
# Surbhi Chandra
# Piyush Sinha
# Nawñeet Siñgh Rājput
# Add Friend
# Muskan Thakur
# Add Friend
# Prince Singh Brothers
# Add Friend
# राजवीर सिंह
# Add Friend
# Kumar Anand
# Add Friend
# Abhinav Raj
# Add Friend
# Shobhit Singh
# Add Friend
# निशांत गौरव
# Add Friend
# Aayush Kumar
# Add Friend
# Aayush Kumar
# Add Friend
# Aman Singh
# Add Friend
# Karan Kartik
# Add Friend
# Akash Kumar Srivastava
# Add Friend
# Ädityá Gáùtam
# Add Friend
# Avinash Rajput
# Add Friend
# Virat Singh
# Add Friend
# See More Friends
# मराठी
# ਪੰਜਾਬੀ
# हिन्दी
# اردو
#  +
# Create Page
# Help
# Settings & Privacy
# Report a Problem
# Terms & Policies
# ...

# %%
print("\n Without any description")
z=0
for j in soup.find_all('a'):
    if z>15:
        print(j.text)
    z=z+1
# Out:
#  Without any description
# 7 Mutual Friends
# Satyam Kapoor
# Add Friend
# Rïtwîk Mishrä
# Add Friend
# Sushank Pandey
# Add Friend
# Umang Kashyap
# Add Friend
# Nihal Kumar
# Add Friend
# Chitransh Ayush
# Add Friend
# Surbhi Chandra
# Piyush Sinha
# Nawñeet Siñgh Rājput
# Add Friend
# Muskan Thakur
# Add Friend
# Prince Singh Brothers
# Add Friend
# राजवीर सिंह
# Add Friend
# Kumar Anand
# Add Friend
# Abhinav Raj
# Add Friend
# Shobhit Singh
# Add Friend
# निशांत गौरव
# Add Friend
# Aayush Kumar
# Add Friend
# Aayush Kumar
# Add Friend
# Aman Singh
# Add Friend
# Karan Kartik
# Add Friend
# Akash Kumar Srivastava
# Add Friend
# Ädityá Gáùtam
# Add Friend
# Avinash Rajput
# Add Friend
# Virat Singh
# Add Friend
# See More Friends
# मराठी
# ਪੰਜਾਬੀ
# हिन्दी
# اردو
#  +
# Create Page
# Help
# Settings & Privacy
# Report a Problem
# Terms & Policies
# Logout (Gaurav Kumar)
# Back To Top

# %%
z=0
for j in soup.find_all('a'):
    if z>15  and j.text.lower() !="see more friends" and j.text.lower() !="add friend":
        print(j.text)
    z=z+1
# Out:
# 7 Mutual Friends
# Satyam Kapoor
# Rïtwîk Mishrä
# Sushank Pandey
# Umang Kashyap
# Nihal Kumar
# Chitransh Ayush
# Surbhi Chandra
# Piyush Sinha
# Nawñeet Siñgh Rājput
# Muskan Thakur
# Prince Singh Brothers
# राजवीर सिंह
# Kumar Anand
# Abhinav Raj
# Shobhit Singh
# निशांत गौरव
# Aayush Kumar
# Aayush Kumar
# Aman Singh
# Karan Kartik
# Akash Kumar Srivastava
# Ädityá Gáùtam
# Avinash Rajput
# Virat Singh
# मराठी
# ਪੰਜਾਬੀ
# हिन्दी
# اردو
#  +
# Create Page
# Help
# Settings & Privacy
# Report a Problem
# Terms & Policies
# Logout (Gaurav Kumar)
# Back To Top

# %%
z=0
for i in soup.find_all('a'):
    if i.text.lower() == "see more friends":
        break
    if z>15 and i.text.lower() !="add friend":
        print(i.text)
    z=z+1
# Out:
# 7 Mutual Friends
# Satyam Kapoor
# Rïtwîk Mishrä
# Sushank Pandey
# Umang Kashyap
# Nihal Kumar
# Chitransh Ayush
# Surbhi Chandra
# Piyush Sinha
# Nawñeet Siñgh Rājput
# Muskan Thakur
# Prince Singh Brothers
# राजवीर सिंह
# Kumar Anand
# Abhinav Raj
# Shobhit Singh
# निशांत गौरव
# Aayush Kumar
# Aayush Kumar
# Aman Singh
# Karan Kartik
# Akash Kumar Srivastava
# Ädityá Gáùtam
# Avinash Rajput
# Virat Singh

# %%
url = "https://mbasic.facebook.com/hindicodingzone"
index = 0
z = []
while(index<6):
    data = requests.get(url, cookies=cj)
    soup = bs4.BeautifulSoup(data.text, 'html.parser')
    print(url)
    for i in soup.find_all('a', href=True):
        if i['href'][0:23] == "/HindiCodingZone/photos":
            z.append(i['href'])
        if i.text.lower() == "show more":
            url = "https://mbasic.facebook.com" +i['href']
    index = index + 1

photos = []
num = 0
for url in z:
    url = "https://mbasic.facebook.com" +url
    data = requests.get(url, cookies=cj)
    soup = bs4.BeautifulSoup(data.text, 'html.parser')
    for i in soup.find_all('a', href=True):
        if i.text.lower() =="view full size":
            photos.append(i['href'])
            urllib.request.urlretrieve(i['href'], str(num) +'.jpg')
            num = num+1

print(len(photos))
print(photos)
