# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#get Available dataset names from here

mpg = sns.load_dataset('mpg')

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.distplot(mpg['cylinders'],bins=8)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(mpg["cylinders"],hist=True,bins=range(3,10,1))
plt.xticks(range(3,9,1))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ([<matplotlib.axis.XTick at 0x1f77ec75cc0>,
#   <matplotlib.axis.XTick at 0x1f77ec754a8>,
#   <matplotlib.axis.XTick at 0x1f77ec75438>,
#   <matplotlib.axis.XTick at 0x1f77ec97470>,
#   <matplotlib.axis.XTick at 0x1f77ecab390>,
#   <matplotlib.axis.XTick at 0x1f77ecab828>],
#  <a list of 6 Text xticklabel objects>)

# %%
dots = sns.load_dataset("dots")

# %%
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# 5    dots     T1   -80       51.2    34.987571
# 6    dots     T1   -60        0.0    32.868526
# 7    dots     T1   -60        3.2    35.119048
# 8    dots     T1   -60        6.4    34.841076
# 9    dots     T1   -60       12.8    35.648148
# 10   dots     T1   -60       25.6    33.610568
# 11   dots     T1   -60       51.2    34.277344
# 12   dots     T1   -40        0.0    34.561753
# 13   dots     T1   -40        3.2    34.895833
# 14   dots     T1   -40        6.4    34.963325
# 15   dots     T1   -40       12.8    36.471193
# 16   dots     T1   -40       25.6    32.534247
# 17   dots     T1   -40       51.2    35.009766
# 18   dots     T1   -20        0.0    35.358566
# 19   dots     T1   -20        3.2    31.101190
# 20   dots     T1   -20        6.4    35.513447
# 21   dots     T1   -20       12.8    34.516461
# 22   dots     T1   -20       25.6    34.784736
# 23   dots     T1   -20       51.2    36.669922
# 24   dots     T1     0        0.0    36.254980
# 25   dots     T1     0        3.2    32.366071
# 26   dots     T1     0        6.4    36.919315
# 27   dots     T1     0       12.8    35.699588
# 28   dots     T1     0       25.6    35.861057
# 29   dots     T1     0       51.2    37.060547
# ..    ...    ...   ...        ...          ...
# 818  sacc     T2   220        0.0    27.562863
# 819  sacc     T2   220        3.2    29.643963
# 820  sacc     T2   220        6.4    29.069767
# 821  sacc     T2   220       12.8    27.148847
# 822  sacc     T2   220       25.6    27.549020
# 823  sacc     T2   220       51.2    30.135659
# 824  sacc     T2   240        0.0    28.675048
# 825  sacc     T2   240        3.2    29.566563
# 826  sacc     T2   240        6.4    29.844961
# 827  sacc     T2   240       12.8    26.991614
# 828  sacc     T2   240       25.6    27.892157
# 829  sacc     T2   240       51.2    30.281008
# 830  sacc     T2   260        0.0    28.820116
# 831  sacc     T2   260        3.2    26.857585
# 832  sacc     T2   260        6.4    29.909561
# 833  sacc     T2   260       12.8    28.144654
# 834  sacc     T2   260       25.6    28.578431
# 835  sacc     T2   260       51.2    31.104651
# 836  sacc     T2   280        0.0    28.675048
# 837  sacc     T2   280        3.2    30.495356
# 838  sacc     T2   280        6.4    27.583979
# 839  sacc     T2   280       12.8    28.511530
# 840  sacc     T2   280       25.6    26.470588
# 841  sacc     T2   280       51.2    30.813953
# 842  sacc     T2   300        0.0    28.384913
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.distplot(mpg["cylinders"],hist=False,bins=range(3,10,1))

# %%
sns.countplot(x='cylinders',data=mpg)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
n=0
for i in mpg['weight'].unique():
    print("value of n is ",n,i)
    n=n+1
# Out:
# value of n is  0 3504
# value of n is  1 3693
# value of n is  2 3436
# value of n is  3 3433
# value of n is  4 3449
# value of n is  5 4341
# value of n is  6 4354
# value of n is  7 4312
# value of n is  8 4425
# value of n is  9 3850
# value of n is  10 3563
# value of n is  11 3609
# value of n is  12 3761
# value of n is  13 3086
# value of n is  14 2372
# value of n is  15 2833
# value of n is  16 2774
# value of n is  17 2587
# value of n is  18 2130
# value of n is  19 1835
# value of n is  20 2672
# value of n is  21 2430
# value of n is  22 2375
# value of n is  23 2234
# value of n is  24 2648
# value of n is  25 4615
# value of n is  26 4376
# value of n is  27 4382
# value of n is  28 4732
# value of n is  29 2264
# value of n is  30 2228
# value of n is  31 2046
# value of n is  32 2634
# value of n is  33 3439
# value of n is  34 3329
# value of n is  35 3302
# value of n is  36 3288
# value of n is  37 4209
# value of n is  38 4464
# value of n is  39 4154
# value of n is  40 4096
# value of n is  41 4955
# value of n is  42 4746
# value of n is  43 5140
# value of n is  44 2962
# value of n is  45 2408
# value of n is  46 3282
# value of n is  47 3139
# value of n is  48 2220
# value of n is  49 2123
# value of n is  50 2074
# value of n is  51 2065
# value of n is  52 1773
# value of n is  53 1613
# value of n is  54 1834
# value of n is  55 1955
# value of n is  56 2278
# value of n is  57 2126
# value of n is  58 2254
# value of n is  59 2226
# value of n is  60 4274
# value of n is  61 4385
# value of n is  62 4135
# value of n is  63 4129
# value of n is  64 3672
# value of n is  65 4633
# value of n is  66 4502
# value of n is  67 4456
# value of n is  68 4422
# value of n is  69 2330
# value of n is  70 3892
# value of n is  71 4098
# value of n is  72 4294
# value of n is  73 4077
# value of n is  74 2933
# value of n is  75 2511
# value of n is  76 2979
# value of n is  77 2189
# value of n is  78 2395
# value of n is  79 2288
# value of n is  80 2506
# value of n is  81 2164
# value of n is  82 2100
# value of n is  83 4100
# value of n is  84 3988
# value of n is  85 4042
# value of n is  86 3777
# value of n is  87 4952
# value of n is  88 4363
# value of n is  89 4237
# value of n is  90 4735
# value of n is  91 4951
# value of n is  92 3821
# value of n is  93 3121
# value of n is  94 3278
# value of n is  95 2945
# value of n is  96 3021
# value of n is  97 2904
# value of n is  98 1950
# value of n is  99 4997
# value of n is  100 4906
# value of n is  101 4654
# value of n is  102 4499
# value of n is  103 2789
# value of n is  104 2279
# value of n is  105 2401
# value of n is  106 2379
# value of n is  107 2124
# value of n is  108 2310
# value of n is  109 2472
# value of n is  110 2265
# value of n is  111 4082
# value of n is  112 4278
# value of n is  113 1867
# value of n is  114 2158
# value of n is  115 2582
# value of n is  116 2868
# value of n is  117 3399
# value of n is  118 2660
# value of n is  119 2807
# value of n is  120 3664
# value of n is  121 3102
# value of n is  122 2875
# value of n is  123 2901
# value of n is  124 3336
# value of n is  125 2451
# value of n is  126 1836
# value of n is  127 2542
# value of n is  128 3781
# value of n is  129 3632
# value of n is  130 3613
# value of n is  131 4141
# value of n is  132 4699
# value of n is  133 4457
# value of n is  134 4638
# value of n is  135 4257
# value of n is  136 2219
# value of n is  137 1963
# value of n is  138 2300
# value of n is  139 1649
# value of n is  140 2003
# value of n is  141 2125
# value of n is  142 2108
# value of n is  143 2246
# value of n is  144 2489
# value of n is  145 2391
# value of n is  146 2000
# value of n is  147 3264
# value of n is  148 3459
# value of n is  149 3432
# value of n is  150 3158
# value of n is  151 4668
# value of n is  152 4440
# value of n is  153 4498
# value of n is  154 4657
# value of n is  155 3907
# value of n is  156 3897
# value of n is  157 3730
# value of n is  158 3785
# value of n is  159 3039
# value of n is  160 3221
# value of n is  161 3169
# value of n is  162 2171
# value of n is  163 2639
# value of n is  164 2914
# value of n is  165 2592
# value of n is  166 2702
# value of n is  167 2223
# value of n is  168 2545
# value of n is  169 2984
# value of n is  170 1937
# value of n is  171 3211
# value of n is  172 2694
# value of n is  173 2957
# value of n is  174 2671
# value of n is  175 1795
# value of n is  176 2464
# value of n is  177 2572
# value of n is  178 2255
# value of n is  179 2202
# value of n is  180 4215
# value of n is  181 4190
# value of n is  182 3962
# value of n is  183 3233
# value of n is  184 3353
# value of n is  185 3012
# value of n is  186 3085
# value of n is  187 2035
# value of n is  188 3651
# value of n is  189 3574
# value of n is  190 3645
# value of n is  191 3193
# value of n is  192 1825
# value of n is  193 1990
# value of n is  194 2155
# value of n is  195 2565
# value of n is  196 3150
# value of n is  197 3940
# value of n is  198 3270
# value of n is  199 2930
# value of n is  200 3820
# value of n is  201 4380
# value of n is  202 4055
# value of n is  203 3870
# value of n is  204 3755
# value of n is  205 2045
# value of n is  206 1945
# value of n is  207 3880
# value of n is  208 4060
# value of n is  209 4140
# value of n is  210 4295
# value of n is  211 3520
# value of n is  212 3425
# value of n is  213 3630
# value of n is  214 3525
# value of n is  215 4220
# value of n is  216 4165
# value of n is  217 4325
# value of n is  218 4335
# value of n is  219 1940
# value of n is  220 2740
# value of n is  221 2755
# value of n is  222 2051
# value of n is  223 2075
# value of n is  224 1985
# value of n is  225 2190
# value of n is  226 2815
# value of n is  227 2600
# value of n is  228 2720
# value of n is  229 1800
# value of n is  230 2070
# value of n is  231 3365
# value of n is  232 3735
# value of n is  233 3570
# value of n is  234 3535
# value of n is  235 3155
# value of n is  236 2965
# value of n is  237 3430
# value of n is  238 3210
# value of n is  239 3380
# value of n is  240 3070
# value of n is  241 3620
# value of n is  242 3410
# value of n is  243 3445
# value of n is  244 3205
# value of n is  245 4080
# value of n is  246 2560
# value of n is  247 2230
# value of n is  248 2515
# value of n is  249 2745
# value of n is  250 2855
# value of n is  251 2405
# value of n is  252 2830
# value of n is  253 3140
# value of n is  254 2795
# value of n is  255 2135
# value of n is  256 3245
# value of n is  257 2990
# value of n is  258 2890
# value of n is  259 3265
# value of n is  260 3360
# value of n is  261 3840
# value of n is  262 3725
# value of n is  263 3955
# value of n is  264 3830
# value of n is  265 4360
# value of n is  266 4054
# value of n is  267 3605
# value of n is  268 1925
# value of n is  269 1975
# value of n is  270 1915
# value of n is  271 2670
# value of n is  272 3530
# value of n is  273 3900
# value of n is  274 3190
# value of n is  275 3420
# value of n is  276 2200
# value of n is  277 2150
# value of n is  278 2020
# value of n is  279 2595
# value of n is  280 2700
# value of n is  281 2556
# value of n is  282 2144
# value of n is  283 1968
# value of n is  284 2120
# value of n is  285 2019
# value of n is  286 2678
# value of n is  287 2870
# value of n is  288 3003
# value of n is  289 3381
# value of n is  290 2188
# value of n is  291 2711
# value of n is  292 2434
# value of n is  293 2110
# value of n is  294 2800
# value of n is  295 2085
# value of n is  296 2335
# value of n is  297 2950
# value of n is  298 3250
# value of n is  299 1850
# value of n is  300 2145
# value of n is  301 1845
# value of n is  302 2910
# value of n is  303 2420
# value of n is  304 2500
# value of n is  305 2905
# value of n is  306 2290
# value of n is  307 2490
# value of n is  308 2635
# value of n is  309 2620
# value of n is  310 2725
# value of n is  311 2385
# value of n is  312 1755
# value of n is  313 1875
# value of n is  314 1760
# value of n is  315 2050
# value of n is  316 2215
# value of n is  317 2380
# value of n is  318 2320
# value of n is  319 2210
# value of n is  320 2350
# value of n is  321 2615
# value of n is  322 3230
# value of n is  323 3160
# value of n is  324 2900
# value of n is  325 3415
# value of n is  326 3060
# value of n is  327 3465
# value of n is  328 2605
# value of n is  329 2640
# value of n is  330 2575
# value of n is  331 2525
# value of n is  332 2735
# value of n is  333 2865
# value of n is  334 3035
# value of n is  335 1980
# value of n is  336 2025
# value of n is  337 1970
# value of n is  338 2160
# value of n is  339 2205
# value of n is  340 2245
# value of n is  341 1965
# value of n is  342 1995
# value of n is  343 3015
# value of n is  344 2585
# value of n is  345 2835
# value of n is  346 2665
# value of n is  347 2370
# value of n is  348 2790
# value of n is  349 2295
# value of n is  350 2625

# %%
sns.countplot(x='weight',data=mpg)

# %%
mpg['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
sns.countplot(x='origin',data=mpg)

# %%
sns.countplot(x='cylinders',data=mpg,color='red',hue='origin')

# %%
sns.countplot(x = 'cylinders', data=mpg, color='blue', hue='origin')
plt.legend(loc='lower rigth')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\legend.py:641: UserWarning: Unrecognized location "lower rigth". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
sns.boxplot(y='acceleration',data=mpg)
plt.xlabel('Acceleration')
# Out:
# Text(0.5,0,'Acceleration')

# %%
mpg['acceleration'].unique()
# Out:
# array([12. , 11.5, 11. , 10.5, 10. ,  9. ,  8.5,  8. ,  9.5, 15. , 15.5,
#        16. , 14.5, 20.5, 17.5, 12.5, 14. , 13.5, 18.5, 19. , 13. , 19.5,
#        18. , 17. , 23.5, 16.5, 21. , 16.9, 14.9, 17.7, 15.3, 13.9, 12.8,
#        15.4, 17.6, 22.2, 22.1, 14.2, 17.4, 16.2, 17.8, 12.2, 16.4, 13.6,
#        15.7, 13.2, 21.9, 16.7, 12.1, 14.8, 18.6, 16.8, 13.7, 11.1, 11.4,
#        18.2, 15.8, 15.9, 14.1, 21.5, 14.4, 19.4, 19.2, 17.2, 18.7, 15.1,
#        13.4, 11.2, 14.7, 16.6, 17.3, 15.2, 14.3, 20.1, 24.8, 11.3, 12.9,
#        18.8, 18.1, 17.9, 21.7, 23.7, 19.9, 21.8, 13.8, 12.6, 16.1, 20.7,
#        18.3, 20.4, 19.6, 17.1, 15.6, 24.6, 11.6])

# %%
num=0
for i in mpg['acceleration'].unique():
    if(i==15):
        num=num+1
        print("value of num",num)
# Out:
# value of num 1

# %%
sns.boxplot(y='acceleration',x='origin',data=mpg)

# %%
sns.boxplot(y='acceleration',x='cylinders',data=mpg)

# %% [markdown]
# # Bivariate distribution

# %%
sns.jointplot(x='horsepower',y='acceleration',data=mpg)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
mpg['horsepower']
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
# 5      198.0
# 6      220.0
# 7      215.0
# 8      225.0
# 9      190.0
# 10     170.0
# 11     160.0
# 12     150.0
# 13     225.0
# 14      95.0
# 15      95.0
# 16      97.0
# 17      85.0
# 18      88.0
# 19      46.0
# 20      87.0
# 21      90.0
# 22      95.0
# 23     113.0
# 24      90.0
# 25     215.0
# 26     200.0
# 27     210.0
# 28     193.0
# 29      88.0
#        ...
# 368     88.0
# 369     88.0
# 370     85.0
# 371     84.0
# 372     90.0
# 373     92.0
# 374      NaN
# 375     74.0
# 376     68.0
# 377     68.0
# 378     63.0
# 379     70.0
# 380     88.0
# 381     75.0
# 382     70.0
# 383     67.0
# 384     67.0
# 385     67.0
# 386    110.0
# 387     85.0
# 388     92.0
# 389    112.0
# 390     96.0
# 391     84.0
# 392     90.0
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
sns.scatterplot(x='horsepower',y='acceleration', data=mpg)

# %%
sns.scatterplot(y='acceleration',x='horsepower', data=mpg, alpha=0.2)

# %%
sns.scatterplot(y="acceleration",x="horsepower",hue='origin',data=mpg)

# %%
plt.subplot(2,2,1)
sns.scatterplot(y="acceleration",x="horsepower",hue='origin',data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower',data=mpg,alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin',data=mpg)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.scatterplot(y="acceleration",x="horsepower",hue='origin',data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower',data=mpg,alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin',data=mpg)

# %%
plt.subplot(2,2,1)
sns.scatterplot(y="acceleration",x="horsepower",hue='origin',data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(y='acceleration',x='horsepower',data=mpg,alpha=0.2)

plt.subplot(2,2,3)
sns.boxplot(y='acceleration',x='origin',data=mpg)


plt.savefig('E:\ML\my_plot.png')

# %%
sns.lmplot(x='horsepower', y='acceleration', data=mpg)

# %%
sns.lmplot(x='horsepower',y='acceleration',hue='origin',data=mpg)

# %%
sns.lmplot(x='horsepower',y='acceleration',col='origin',data=mpg)

# %%
sns.lmplot(x='horsepower',y='acceleration',row='origin',data=mpg)

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips['sex'].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
tips['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
tips['tip'].unique()
# Out:
# array([ 1.01,  1.66,  3.5 ,  3.31,  3.61,  4.71,  2.  ,  3.12,  1.96,
#         3.23,  1.71,  5.  ,  1.57,  3.  ,  3.02,  3.92,  1.67,  3.71,
#         3.35,  4.08,  2.75,  2.23,  7.58,  3.18,  2.34,  4.3 ,  1.45,
#         2.5 ,  2.45,  3.27,  3.6 ,  3.07,  2.31,  2.24,  2.54,  3.06,
#         1.32,  5.6 ,  6.  ,  2.05,  2.6 ,  5.2 ,  1.56,  4.34,  3.51,
#         1.5 ,  1.76,  6.73,  3.21,  1.98,  3.76,  2.64,  3.15,  2.47,
#         1.  ,  2.01,  2.09,  1.97,  3.14,  2.2 ,  1.25,  3.08,  4.  ,
#         2.71,  3.4 ,  1.83,  2.03,  5.17,  5.85,  3.25,  4.73,  3.48,
#         1.64,  4.06,  4.29,  2.55,  5.07,  1.8 ,  2.92,  1.68,  2.52,
#         4.2 ,  1.48,  2.18,  2.83,  6.7 ,  2.3 ,  1.36,  1.63,  1.73,
#         2.74,  5.14,  3.75,  2.61,  4.5 ,  1.61, 10.  ,  3.16,  5.15,
#         3.11,  3.55,  3.68,  5.65,  6.5 ,  4.19,  2.56,  2.02,  1.44,
#         3.41,  5.16,  9.  ,  1.1 ,  3.09,  1.92,  1.58,  2.72,  2.88,
#         3.39,  1.47,  1.17,  4.67,  5.92,  1.75])

# %%
tips['smoker'].unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
tips.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# 5         False  False  False   False  False  False  False
# 6         False  False  False   False  False  False  False
# 7         False  False  False   False  False  False  False
# 8         False  False  False   False  False  False  False
# 9         False  False  False   False  False  False  False
# 10        False  False  False   False  False  False  False
# 11        False  False  False   False  False  False  False
# 12        False  False  False   False  False  False  False
# 13        False  False  False   False  False  False  False
# 14        False  False  False   False  False  False  False
# 15        False  False  False   False  False  False  False
# 16        False  False  False   False  False  False  False
# 17        False  False  False   False  False  False  False
# 18        False  False  False   False  False  False  False
# 19        False  False  False   False  False  False  False
# 20        False  False  False   False  False  False  False
# 21        False  False  False   False  False  False  False
# 22        False  False  False   False  False  False  False
# 23        False  False  False   False  False  False  False
# 24        False  False  False   False  False  False  False
# 25        False  False  False   False  False  False  False
# 26        False  False  False   False  False  False  False
# 27        False  False  False   False  False  False  False
# 28        False  False  False   False  False  False  False
# 29        False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 214       False  False  False   False  False  False  False
# 215       False  False  False   False  False  False  False
# 216       False  False  False   False  False  False  False
# 217       False  False  False   False  False  False  False
# 218       False  False  False   False  False  False  False
# 219       False  False  False   False  False  False  False
# 220       False  False  False   False  False  False  False
# 221       False  False  False   False  False  False  False
# 222       False  False  False   False  False  False  False
# 223       False  False  False   False  False  False  False
# 224       False  False  False   False  False  False  False
# 225       False  False  False   False  False  False  False
# 226       False  False  False   False  False  False  False
# 227       False  False  False   False  False  False  False
# 228       False  False  False   False  False  False  False
# 229       False  False  False   False  False  False  False
# 230       False  False  False   False  False  False  False
# 231       False  False  False   False  False  False  False
# 232       False  False  False   False  False  False  False
# 233       False  False  False   False  False  False  False
# 234       False  False  False   False  False  False  False
# 235       False  False  False   False  False  False  False
# 236       False  False  False   False  False  False  False
# 237       False  False  False   False  False  False  False
# 238       False  False  False   False  False  False  False
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x=tips['tip'],color='green')

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
tips['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
sns.set()
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", col="time",
            hue="smoker", style="smoker", size="size",
            data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="violin", split=True, data=tips);

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for m, zlow, zhigh in [('o', -50, -25), ('^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = wines['residual sugar']
ys = wines['fixed acidity']
zs = wines['alcohol']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Residual Sugar')
ax.set_ylabel('Fixed Acidity')
ax.set_zlabel('Alcohol')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-64a4c79caa33> in <module>()
#       2 ax = fig.add_subplot(111, projection='3d')
#       3
# ----> 4 xs = wines['residual sugar']
#       5 ys = wines['fixed acidity']
#       6 zs = wines['alcohol']
#
# NameError: name 'wines' is not defined
